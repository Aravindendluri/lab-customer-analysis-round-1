# %%
import pandas as pd
import numpy as  np
file1 = pd.read_csv('files_for_lab/csv_files/file1.csv')
file2 = pd.read_csv('files_for_lab/csv_files/file2.csv')
file3 = pd.read_csv('files_for_lab/csv_files/file3.csv')

# %%
file1.columns
file2.columns
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
 file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
Nfile1= [file1.columns[i].lower().replace(' ','_') for i in range(len(file1.columns))] 

Nfile1
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
Nfile1= file1.columns
Nfile1
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
Nfile2= [file2.columns[i].lower().replace(' ','_') for i in range(len(file2.columns))]
Nfile2
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class']

# %%
file2.columns= Nfile2
Nfile2
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class']

# %%
Nfile3 = [file3.columns[i].lower().replace(' ', '_') for i in range(len(file3.columns))] 
Nfile3
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
file3.columns= Nfile3
Nfile3
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
data = pd.concat([file1,file2,file3])

# %%
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data._get_numeric_data().columns
# Out:
# Index(['Income', 'Monthly Premium Auto', 'Total Claim Amount'], dtype='object')

# %%
numerical = list(data.select_dtypes(include=[np.number]).columns.values)
numerical
# Out:
# ['Income', 'Monthly Premium Auto', 'Total Claim Amount']

# %%
categorical = list(data.select_dtypes(['object']).columns.values)
categorical
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'State',
#  'Gender']

# %%
100* data['Customer Lifetime Value']
# Out:
# 0                                                     NaN
# 1       697953.59%697953.59%697953.59%697953.59%697953...
# 2       1288743.17%1288743.17%1288743.17%1288743.17%12...
# 3       764586.18%764586.18%764586.18%764586.18%764586...
# 4       536307.65%536307.65%536307.65%536307.65%536307...
#                               ...
# 7065                                          2340598.798
# 7066                                          309651.1217
# 7067                                          816389.0428
# 7068                                          752444.2436
# 7069                                          261183.6866
# Name: Customer Lifetime Value, Length: 12074, dtype: object

# %%
data.drop(['education','number_of_open_complaints'], axis = 1)
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data2 = data.drop_duplicates(keep=False)
data2
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
 data3 = data2.loc[data2['income']>0]

# %%
data3
# Out:
#      customer          st gender             education  \
# 2     AI49188      Nevada      F              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# 6     XZ87318      Oregon      F               College
# 8     DY87989      Oregon      M              Bachelor
# ...       ...         ...    ...                   ...
# 7063  TF56202         NaN      M               College
# 7064  YM19146         NaN      F               College
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7068  UP19263         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 2                1288743.17%  48767.0                 108.0
# 4                 536307.65%  36357.0                  68.0
# 5                 825629.78%  62902.0                  69.0
# ...
